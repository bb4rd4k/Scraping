# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
URL = 'https://www.monster.com/jobs/search/?q=optic-engineer&where=Los-Angeles__2C-CA'

# %%
page = requests.get(URL)

# %%
print(page.text)
# Out:
# <!DOCTYPE html>
# <html xmlns="https://www.w3.org/1999/xhtml" xml:lang="en" lang="en">
# <head>
#         <script>
#         //Collect all document ready function or handler and put it in queue where it will be executed once the Jquery is loaded
#         (function (w, d, u) {
#             w.readyQ = [];
#             w.bindReadyQ = [];
#             w.loadQ = [];
#             w.bindLoadQ = [];
#
#             function p(x, y) {
#                 if (x == "ready") {
#                     w.bindReadyQ.push(y);
#                 } else {
#                     w.readyQ.push(x);
#                 }
#             };
#             function q(x, y) {
#                 if (x == "load") {
#                     w.bindLoadQ.push(y);
#                 } else {
#                     w.loadQ.push(x);
#                 }
#             };
#             var a = {
#                 ready: p,
#                 bind: p
#             };
#             var b = {
#                 load: q,
# ...
